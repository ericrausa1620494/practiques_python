# %% [markdown]
# # exemple random

# %%
import numpy as np

# %%
a=np.random.uniform(-1,1)
print(a)
# Out:
# 0.5175921635810186

# %%
b=np.random.randint(1,6) #per numeros sencers només
print(b)
# Out:
# 3
